# %% [markdown]
# # Find a Legend Challenge - Submission Notebook
#
# This notebook is designed to work with as few external files needed.
# Unfortunately the OCR Tool use (tesseract) needs to be installed manually as a executable.
# For a windows machine we suggest using the installer provided here: https://github.com/UB-Mannheim/tesseract/wiki (standard configuration will save the files to expected the target location). Feel free to install tesseract in other ways, but notice that we cannot assure all paths are working correctly.
#
#
# Competition:  https://xeek.ai/challenges/extract-crossplot-markers <br>
# Repository: https://github.com/REDA-solutions/PlotLegendDetectionCV

# %%
team_name = 'REDA solutions' 
model_name = 'legend_detection_model'

# %% [markdown]
# ## Imports

# %%
! pip install -r requirements.txt --user
# Out:
# Collecting numpy==1.23.3
#   Downloading numpy-1.23.3-cp39-cp39-win_amd64.whl (14.7 MB)
#      ---------------------------------------- 14.7/14.7 MB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: opencv_python==4.6.0.66 in c:\users\schla\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (4.6.0.66)
# Requirement already satisfied: pandas==1.5.1 in c:\users\schla\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (1.5.1)
# Collecting Pillow==9.3.0
#   Downloading Pillow-9.3.0-cp39-cp39-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: pytesseract==0.3.10 in c:\users\schla\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (0.3.10)
# Requirement already satisfied: torch==1.13.0 in c:\users\schla\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (1.13.0)
# Requirement already satisfied: torchvision==0.14.0 in c:\users\schla\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (0.14.0)
# Requirement already satisfied: tqdm==4.64.1 in c:\users\schla\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (4.64.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\schla\anaconda3\lib\site-packages (from pandas==1.5.1->-r requirements.txt (line 3)) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\schla\anaconda3\lib\site-packages (from pandas==1.5.1->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\schla\anaconda3\lib\site-packages (from pytesseract==0.3.10->-r requirements.txt (line 5)) (21.3)
# Requirement already satisfied: typing-extensions in c:\users\schla\anaconda3\lib\site-packages (from torch==1.13.0->-r requirements.txt (line 6)) (4.3.0)
# Requirement already satisfied: requests in c:\users\schla\anaconda3\lib\site-packages (from torchvision==0.14.0->-r requirements.txt (line 7)) (2.28.1)
# Requirement already satisfied: colorama in c:\users\schla\anaconda3\lib\site-packages (from tqdm==4.64.1->-r requirements.txt (line 8)) (0.4.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\schla\anaconda3\lib\site-packages (from packaging>=21.3->pytesseract==0.3.10->-r requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\schla\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas==1.5.1->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\schla\anaconda3\lib\site-packages (from requests->torchvision==0.14.0->-r requirements.txt (line 7)) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\schla\anaconda3\lib\site-packages (from requests->torchvision==0.14.0->-r requirements.txt (line 7)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\schla\anaconda3\lib\site-packages (from requests->torchvision==0.14.0->-r requirements.txt (line 7)) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\schla\anaconda3\lib\site-packages (from requests->torchvision==0.14.0->-r requirements.txt (line 7)) (2.0.4)
# Installing collected packages: Pillow, numpy
# Successfully installed Pillow-9.3.0 numpy-1.23.3
#   WARNING: The script f2py.exe is installed in 'C:\Users\schla\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.23.1 requires regex!=2019.12.17, which is not installed.
# tensorflow 2.7.0 requires h5py>=2.9.0, which is not installed.

# %%
import os
import platform
import sys
import numpy as np
import pandas as pd
from glob import glob
import torch
import re

from models_ocr.preprocessing.preprocessor import Preprocessor # import of our class --> see repository
from models_ocr.pytesseract_model import PytesseractModel # import of our class --> see repository

# %% [markdown]
# ## Description

# %% [markdown]
# ![Model Architecture](misc/model_architecture.png)

# %% [markdown]
# ## Submission inference pipeline

# %%
from time import perf_counter

# %%
TEST_DATA_ROOT = "raw_data/helvetios_challenge_dataset_test"
TEST_IMAGE_DATASET_PATH = f"{TEST_DATA_ROOT}/images"
TEST_LABELS_DATA_PATH = f"{TEST_DATA_ROOT}/labels"
TEST_INFERENCE_RESULTS_PATH = f"results"

# %%
def run_inference_pipeline(TEST_IMAGE_DATASET_PATH, TEST_INFERENCE_RESULTS_PATH):
   
   print(f"* OS                          : {platform.system()}, {platform.release()}")
   python_version = str(sys.version).replace('\n', ' ')
   print(f"* Python version              : {python_version}")

   os.makedirs(TEST_INFERENCE_RESULTS_PATH, exist_ok=True)
         
   ts_start = perf_counter()
   
   model = torch.hub.load('../yolov5/', 'custom', path='models_detection/best.pt', source='local')
   model.conf = 0.2 # define minimal confidence for found legends
   preprocessor = Preprocessor(deskew=True)
   tesseract = PytesseractModel(preprocessor=preprocessor, confidence=15, custom_config=r"-l eng --psm 11")

   imgs = TEST_IMAGE_DATASET_PATH + r'/*.png'  
   imgs = list(glob(imgs))
   
   results = []
   sample_names = []

   for img in imgs:
      # apply best.pt to the images in the source path
      legends = model(img)
      # crop the image - the next steps will only look at the part of the img detected as legend (kan be multiple frames)
      legends = legends.crop()
      if len(legends) == 0:
         # action if no legend was found
         results.append(np.nan)
      else:
         predictions = []
         for legend_ in legends:
            legend = legend_['im']
            # use the parameterized pytesseract model to predict the legend text
            prediction = tesseract.predict(legend)
            predictions.extend(prediction)

         # some alignments to assure the detected text matches the expected syntax of legend values
         reg = re.compile('/[^0-9]/g')
         predictions = [s for s in predictions if not any(chr.isdigit() for chr in s)]
         predictions = [s for s in predictions if len(s)!=1 or not s.islower()]
         prediction_str = "["
         for word in predictions: prediction_str += f"'{word}' "
         prediction_str = prediction_str.strip()
         prediction_str += "]"
         if prediction_str == "[]":
            prediction_str = np.nan
         results.append(prediction_str)
      sample_names.append(img.split("\\")[1])
   
   ts_after_test = perf_counter()
   
   print(f"Inference time: {ts_after_test-ts_start:.2f} sec.")
   
   inference_results = {'sample_name': sample_names,
                        'legend': results}
   inference_results_df = pd.DataFrame(inference_results)
      
   inference_results_df.to_csv(f"{TEST_INFERENCE_RESULTS_PATH}/{team_name}_{model_name}_results.csv", index = False)
   
   print(inference_results_df)

   print(f"The submission file   : {TEST_INFERENCE_RESULTS_PATH}/{team_name}_{model_name}_results.csv")

# %%
run_inference_pipeline(TEST_IMAGE_DATASET_PATH, TEST_INFERENCE_RESULTS_PATH)
# Out:
# * OS                          : Windows, 10
# * Python version              : 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
# YOLOv5  v7.0-10-g10c025d Python-3.9.7 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# Saved 1 image to runs\detect\exp303
# Saved results to runs\detect\exp303
#
# Saved 1 image to runs\detect\exp304
# Saved results to runs\detect\exp304
#
# Saved 1 image to runs\detect\exp305
# Saved results to runs\detect\exp305
#
# Saved 1 image to runs\detect\exp306
# Saved results to runs\detect\exp306
#
# Saved 1 image to runs\detect\exp307
# Saved results to runs\detect\exp307
#
# Saved 1 image to runs\detect\exp308
# Saved results to runs\detect\exp308
#
# Saved 1 image to runs\detect\exp309
# Saved results to runs\detect\exp309
#
# Saved 1 image to runs\detect\exp310
# Saved results to runs\detect\exp310
#
# Saved 1 image to runs\detect\exp311
# Saved results to runs\detect\exp311
#
# Saved 1 image to runs\detect\exp312
# Saved results to runs\detect\exp312
#
# Saved 1 image to runs\detect\exp313
# Saved results to runs\detect\exp313
#
# Saved 1 image to runs\detect\exp314
# Saved results to runs\detect\exp314
#
# Saved 1 image to runs\detect\exp315
# Saved results to runs\detect\exp315
#
# Saved 1 image to runs\detect\exp316
# Saved results to runs\detect\exp316
#
# Saved 1 image to runs\detect\exp317
# Saved results to runs\detect\exp317
#
# Saved 1 image to runs\detect\exp318
# Saved results to runs\detect\exp318
#
# Saved 1 image to runs\detect\exp319
# Saved results to runs\detect\exp319
#
# Saved 1 image to runs\detect\exp320
# Saved results to runs\detect\exp320
#
# Saved 1 image to runs\detect\exp321
# Saved results to runs\detect\exp321
#
# Saved 1 image to runs\detect\exp322
# Saved results to runs\detect\exp322
#
# Saved 1 image to runs\detect\exp323
# Saved results to runs\detect\exp323
#
# Saved 1 image to runs\detect\exp324
# Saved results to runs\detect\exp324
#
# Saved 1 image to runs\detect\exp325
# Saved results to runs\detect\exp325
#
# Saved 1 image to runs\detect\exp326
# Saved results to runs\detect\exp326
#
# Saved 1 image to runs\detect\exp327
# Saved results to runs\detect\exp327
#
# Saved 1 image to runs\detect\exp328
# Saved results to runs\detect\exp328
#
# Saved 1 image to runs\detect\exp329
# Saved results to runs\detect\exp329
#
# Saved 1 image to runs\detect\exp330
# Saved results to runs\detect\exp330
#
# Saved 1 image to runs\detect\exp331
# Saved results to runs\detect\exp331
#
# Saved 1 image to runs\detect\exp332
# Saved results to runs\detect\exp332
#
# Saved 1 image to runs\detect\exp333
# Saved results to runs\detect\exp333
#
# Saved 1 image to runs\detect\exp334
# Saved results to runs\detect\exp334
#
# Saved 1 image to runs\detect\exp335
# Saved results to runs\detect\exp335
#
# Saved 1 image to runs\detect\exp336
# Saved results to runs\detect\exp336
#
# Saved 1 image to runs\detect\exp337
# Saved results to runs\detect\exp337
#
# Saved 1 image to runs\detect\exp338
# Saved results to runs\detect\exp338
#
# Saved 1 image to runs\detect\exp339
# Saved results to runs\detect\exp339
#
# Saved 1 image to runs\detect\exp340
# Saved results to runs\detect\exp340
#
# Saved 1 image to runs\detect\exp341
# Saved results to runs\detect\exp341
#
# Saved 1 image to runs\detect\exp342
# Saved results to runs\detect\exp342
#
# Saved 1 image to runs\detect\exp343
# Saved results to runs\detect\exp343
#
# Saved 1 image to runs\detect\exp344
# Saved results to runs\detect\exp344
#
# Saved 1 image to runs\detect\exp345
# Saved results to runs\detect\exp345
#
# Saved 1 image to runs\detect\exp346
# Saved results to runs\detect\exp346
#
# Saved 1 image to runs\detect\exp347
# Saved results to runs\detect\exp347
#
# Saved 1 image to runs\detect\exp348
# Saved results to runs\detect\exp348
#
# Saved 1 image to runs\detect\exp349
# Saved results to runs\detect\exp349
#
# Saved 1 image to runs\detect\exp350
# Saved results to runs\detect\exp350
#
# Saved 1 image to runs\detect\exp351
# Saved results to runs\detect\exp351
#
# Saved 1 image to runs\detect\exp352
# Saved results to runs\detect\exp352
#
# Saved 1 image to runs\detect\exp353
# Saved results to runs\detect\exp353
#
# Saved 1 image to runs\detect\exp354
# Saved results to runs\detect\exp354
#
# Saved 1 image to runs\detect\exp355
# Saved results to runs\detect\exp355
#
# Saved 1 image to runs\detect\exp356
# Saved results to runs\detect\exp356
#
# Saved 1 image to runs\detect\exp357
# Saved results to runs\detect\exp357
#
# Saved 1 image to runs\detect\exp358
# Saved results to runs\detect\exp358
#
# Saved 1 image to runs\detect\exp359
# Saved results to runs\detect\exp359
#
# Saved 1 image to runs\detect\exp360
# Saved results to runs\detect\exp360
#
# Saved 1 image to runs\detect\exp361
# Saved results to runs\detect\exp361
#
# Saved 1 image to runs\detect\exp362
# Saved results to runs\detect\exp362
#
# Saved 1 image to runs\detect\exp363
# Saved results to runs\detect\exp363
#
# Saved 1 image to runs\detect\exp364
# Saved results to runs\detect\exp364
#
# Saved 1 image to runs\detect\exp365
# Saved results to runs\detect\exp365
#
# Saved 1 image to runs\detect\exp366
# Saved results to runs\detect\exp366
#
# Saved 1 image to runs\detect\exp367
# Saved results to runs\detect\exp367
#
# Saved 1 image to runs\detect\exp368
# Saved results to runs\detect\exp368
#
# Saved 1 image to runs\detect\exp369
# Saved results to runs\detect\exp369
#
# Saved 1 image to runs\detect\exp370
# Saved results to runs\detect\exp370
#
# Saved 1 image to runs\detect\exp371
# Saved results to runs\detect\exp371
#
# Saved 1 image to runs\detect\exp372
# Saved results to runs\detect\exp372
#
# Saved 1 image to runs\detect\exp373
# Saved results to runs\detect\exp373
#
# Saved 1 image to runs\detect\exp374
# Saved results to runs\detect\exp374
#
# Saved 1 image to runs\detect\exp375
# Saved results to runs\detect\exp375
#
# Saved 1 image to runs\detect\exp376
# Saved results to runs\detect\exp376
#
# Saved 1 image to runs\detect\exp377
# Saved results to runs\detect\exp377
#
# Saved 1 image to runs\detect\exp378
# Saved results to runs\detect\exp378
#
# Saved 1 image to runs\detect\exp379
# Saved results to runs\detect\exp379
#
# Saved 1 image to runs\detect\exp380
# Saved results to runs\detect\exp380
#
# Saved 1 image to runs\detect\exp381
# Saved results to runs\detect\exp381
#
# Saved 1 image to runs\detect\exp382
# Saved results to runs\detect\exp382
#
# Saved 1 image to runs\detect\exp383
# Saved results to runs\detect\exp383
#
# Saved 1 image to runs\detect\exp384
# Saved results to runs\detect\exp384
#
# Saved 1 image to runs\detect\exp385
# Saved results to runs\detect\exp385
#
# Saved 1 image to runs\detect\exp386
# Saved results to runs\detect\exp386
#
# Saved 1 image to runs\detect\exp387
# Saved results to runs\detect\exp387
#
# Saved 1 image to runs\detect\exp388
# Saved results to runs\detect\exp388
#
# Saved 1 image to runs\detect\exp389
# Saved results to runs\detect\exp389
#
# Saved 1 image to runs\detect\exp390
# Saved results to runs\detect\exp390
#
# Saved 1 image to runs\detect\exp391
# Saved results to runs\detect\exp391
#
# Saved 1 image to runs\detect\exp392
# Saved results to runs\detect\exp392
#
# Saved 1 image to runs\detect\exp393
# Saved results to runs\detect\exp393
#
# Saved 1 image to runs\detect\exp394
# Saved results to runs\detect\exp394
#
# Saved 1 image to runs\detect\exp395
# Saved results to runs\detect\exp395
#
# Saved 1 image to runs\detect\exp396
# Saved results to runs\detect\exp396
#
# Saved 1 image to runs\detect\exp397
# Saved results to runs\detect\exp397
#
# Saved 1 image to runs\detect\exp398
# Saved results to runs\detect\exp398
#
# Saved 1 image to runs\detect\exp399
# Saved results to runs\detect\exp399
#
# Saved 1 image to runs\detect\exp400
# Saved results to runs\detect\exp400
#
# Saved 1 image to runs\detect\exp401
# Saved results to runs\detect\exp401
#
# Saved 1 image to runs\detect\exp402
# Saved results to runs\detect\exp402
#
# Saved 1 image to runs\detect\exp403
# Saved results to runs\detect\exp403
#
# Saved 1 image to runs\detect\exp404
# Saved results to runs\detect\exp404
#
# Saved 1 image to runs\detect\exp405
# Saved results to runs\detect\exp405
#
# Saved 1 image to runs\detect\exp406
# Saved results to runs\detect\exp406
#
# Saved 1 image to runs\detect\exp407
# Saved results to runs\detect\exp407
#
# Saved 1 image to runs\detect\exp408
# Saved results to runs\detect\exp408
#
# Saved 1 image to runs\detect\exp409
# Saved results to runs\detect\exp409
#
# Saved 1 image to runs\detect\exp410
# Saved results to runs\detect\exp410
#
# Saved 1 image to runs\detect\exp411
# Saved results to runs\detect\exp411
#
# Saved 1 image to runs\detect\exp412
# Saved results to runs\detect\exp412
#
# Saved 1 image to runs\detect\exp413
# Saved results to runs\detect\exp413
#
# Saved 1 image to runs\detect\exp414
# Saved results to runs\detect\exp414
#
# Saved 1 image to runs\detect\exp415
# Saved results to runs\detect\exp415
#
# Saved 1 image to runs\detect\exp416
# Saved results to runs\detect\exp416
#
# Saved 1 image to runs\detect\exp417
# Saved results to runs\detect\exp417
#
# Saved 1 image to runs\detect\exp418
# Saved results to runs\detect\exp418
#
# Saved 1 image to runs\detect\exp419
# Saved results to runs\detect\exp419
#
# Saved 1 image to runs\detect\exp420
# Saved results to runs\detect\exp420
#
# Saved 1 image to runs\detect\exp421
# Saved results to runs\detect\exp421
#
# Saved 1 image to runs\detect\exp422
# Saved results to runs\detect\exp422
#
# Saved 1 image to runs\detect\exp423
# Saved results to runs\detect\exp423
#
# Saved 1 image to runs\detect\exp424
# Saved results to runs\detect\exp424
#
# Saved 1 image to runs\detect\exp425
# Saved results to runs\detect\exp425
#
# Saved 1 image to runs\detect\exp426
# Saved results to runs\detect\exp426
#
# Saved 1 image to runs\detect\exp427
# Saved results to runs\detect\exp427
#
# Saved 1 image to runs\detect\exp428
# Saved results to runs\detect\exp428
#
# Saved 1 image to runs\detect\exp429
# Saved results to runs\detect\exp429
#
# Saved 1 image to runs\detect\exp430
# Saved results to runs\detect\exp430
#
# Saved 1 image to runs\detect\exp431
# Saved results to runs\detect\exp431
#
# Saved 1 image to runs\detect\exp432
# Saved results to runs\detect\exp432
#
# Saved 1 image to runs\detect\exp433
# Saved results to runs\detect\exp433
#
# Saved 1 image to runs\detect\exp434
# Saved results to runs\detect\exp434
#
# Saved 1 image to runs\detect\exp435
# Saved results to runs\detect\exp435
#
# Saved 1 image to runs\detect\exp436
# Saved results to runs\detect\exp436
#
# Saved 1 image to runs\detect\exp437
# Saved results to runs\detect\exp437
#
# Saved 1 image to runs\detect\exp438
# Saved results to runs\detect\exp438
#
# Saved 1 image to runs\detect\exp439
# Saved results to runs\detect\exp439
#
# Saved 1 image to runs\detect\exp440
# Saved results to runs\detect\exp440
#
# Saved 1 image to runs\detect\exp441
# Saved results to runs\detect\exp441
#
# Saved 1 image to runs\detect\exp442
# Saved results to runs\detect\exp442
#
# Saved 1 image to runs\detect\exp443
# Saved results to runs\detect\exp443
#
# Saved 1 image to runs\detect\exp444
# Saved results to runs\detect\exp444
#
# Saved 1 image to runs\detect\exp445
# Saved results to runs\detect\exp445
#
# Saved 1 image to runs\detect\exp446
# Saved results to runs\detect\exp446
#
# Saved 1 image to runs\detect\exp447
# Saved results to runs\detect\exp447
#
# Saved 1 image to runs\detect\exp448
# Saved results to runs\detect\exp448
#
# Saved 1 image to runs\detect\exp449
# Saved results to runs\detect\exp449
#
# Saved 1 image to runs\detect\exp450
# Saved results to runs\detect\exp450
#
# Saved 1 image to runs\detect\exp451
# Saved results to runs\detect\exp451
#
# Saved 1 image to runs\detect\exp452
# Saved results to runs\detect\exp452
#
# Saved 1 image to runs\detect\exp453
# Saved results to runs\detect\exp453
#
# Saved 1 image to runs\detect\exp454
# Saved results to runs\detect\exp454
#
# Saved 1 image to runs\detect\exp455
# Saved results to runs\detect\exp455
#
# Saved 1 image to runs\detect\exp456
# Saved results to runs\detect\exp456
#
# Saved 1 image to runs\detect\exp457
# Saved results to runs\detect\exp457
#
# Saved 1 image to runs\detect\exp458
# Saved results to runs\detect\exp458
#
# Saved 1 image to runs\detect\exp459
# Saved results to runs\detect\exp459
#
# Saved 1 image to runs\detect\exp460
# Saved results to runs\detect\exp460
#
# Saved 1 image to runs\detect\exp461
# Saved results to runs\detect\exp461
#
# Saved 1 image to runs\detect\exp462
# Saved results to runs\detect\exp462
#
# Saved 1 image to runs\detect\exp463
# Saved results to runs\detect\exp463
#
# Saved 1 image to runs\detect\exp464
# Saved results to runs\detect\exp464
#
# Saved 1 image to runs\detect\exp465
# Saved results to runs\detect\exp465
#
# Saved 1 image to runs\detect\exp466
# Saved results to runs\detect\exp466
#
# Saved 1 image to runs\detect\exp467
# Saved results to runs\detect\exp467
#
# Saved 1 image to runs\detect\exp468
# Saved results to runs\detect\exp468
#
# Saved 1 image to runs\detect\exp469
# Saved results to runs\detect\exp469
#
# Saved 1 image to runs\detect\exp470
# Saved results to runs\detect\exp470
#
# Saved 1 image to runs\detect\exp471
# Saved results to runs\detect\exp471
#
# Saved 1 image to runs\detect\exp472
# Saved results to runs\detect\exp472
#
# Saved 1 image to runs\detect\exp473
# Saved results to runs\detect\exp473
#
# Saved 1 image to runs\detect\exp474
# Saved results to runs\detect\exp474
#
# Saved 1 image to runs\detect\exp475
# Saved results to runs\detect\exp475
#
# Saved 1 image to runs\detect\exp476
# Saved results to runs\detect\exp476
#
# Saved 1 image to runs\detect\exp477
# Saved results to runs\detect\exp477
#
# Saved 1 image to runs\detect\exp478
# Saved results to runs\detect\exp478
#
# Saved 1 image to runs\detect\exp479
# Saved results to runs\detect\exp479
#
# Saved 1 image to runs\detect\exp480
# Saved results to runs\detect\exp480
#
# Saved 1 image to runs\detect\exp481
# Saved results to runs\detect\exp481
#
# Saved 1 image to runs\detect\exp482
# Saved results to runs\detect\exp482
#
# Saved 1 image to runs\detect\exp483
# Saved results to runs\detect\exp483
#
# Saved 1 image to runs\detect\exp484
# Saved results to runs\detect\exp484
#
# Saved 1 image to runs\detect\exp485
# Saved results to runs\detect\exp485
#
# Saved 1 image to runs\detect\exp486
# Saved results to runs\detect\exp486
#
# Saved 1 image to runs\detect\exp487
# Saved results to runs\detect\exp487
#
# Saved 1 image to runs\detect\exp488
# Saved results to runs\detect\exp488
#
# Saved 1 image to runs\detect\exp489
# Saved results to runs\detect\exp489
#
# Saved 1 image to runs\detect\exp490
# Saved results to runs\detect\exp490
#
# Saved 1 image to runs\detect\exp491
# Saved results to runs\detect\exp491
#
# Saved 1 image to runs\detect\exp492
# Saved results to runs\detect\exp492
#
# Saved 1 image to runs\detect\exp493
# Saved results to runs\detect\exp493
#
# Saved 1 image to runs\detect\exp494
# Saved results to runs\detect\exp494
#
# Saved 1 image to runs\detect\exp495
# Saved results to runs\detect\exp495
#
# Saved 1 image to runs\detect\exp496
# Saved results to runs\detect\exp496
#
# Saved 1 image to runs\detect\exp497
# Saved results to runs\detect\exp497
#
# Saved 1 image to runs\detect\exp498
# Saved results to runs\detect\exp498
#
# Saved 1 image to runs\detect\exp499
# Saved results to runs\detect\exp499
#
# Saved 1 image to runs\detect\exp500
# Saved results to runs\detect\exp500
#
# Saved 1 image to runs\detect\exp501
# Saved results to runs\detect\exp501
#
# Saved 1 image to runs\detect\exp502
# Saved results to runs\detect\exp502
#
# Saved 1 image to runs\detect\exp503
# Saved results to runs\detect\exp503
#
# Saved 1 image to runs\detect\exp504
# Saved results to runs\detect\exp504
#
# Saved 1 image to runs\detect\exp505
# Saved results to runs\detect\exp505
#
# Saved 1 image to runs\detect\exp506
# Saved results to runs\detect\exp506
#
# Saved 1 image to runs\detect\exp507
# Saved results to runs\detect\exp507
#
# Saved 1 image to runs\detect\exp508
# Saved results to runs\detect\exp508
#
# Saved 1 image to runs\detect\exp509
# Saved results to runs\detect\exp509
#
# Saved 1 image to runs\detect\exp510
# Saved results to runs\detect\exp510
#
# Saved 1 image to runs\detect\exp511
# Saved results to runs\detect\exp511
#
# Saved 1 image to runs\detect\exp512
# Saved results to runs\detect\exp512
#
# Saved 1 image to runs\detect\exp513
# Saved results to runs\detect\exp513
#
# Saved 1 image to runs\detect\exp514
# Saved results to runs\detect\exp514
#
# Saved 1 image to runs\detect\exp515
# Saved results to runs\detect\exp515
#
# Saved 1 image to runs\detect\exp516
# Saved results to runs\detect\exp516
#
# Saved 1 image to runs\detect\exp517
# Saved results to runs\detect\exp517
#
# Saved 1 image to runs\detect\exp518
# Saved results to runs\detect\exp518
#
# Saved 1 image to runs\detect\exp519
# Saved results to runs\detect\exp519
#
# Saved 1 image to runs\detect\exp520
# Saved results to runs\detect\exp520
#
# Saved 1 image to runs\detect\exp521
# Saved results to runs\detect\exp521
#
# Saved 1 image to runs\detect\exp522
# Saved results to runs\detect\exp522
#
# Saved 1 image to runs\detect\exp523
# Saved results to runs\detect\exp523
#
# Saved 1 image to runs\detect\exp524
# Saved results to runs\detect\exp524
#
# Saved 1 image to runs\detect\exp525
# Saved results to runs\detect\exp525
#
# Saved 1 image to runs\detect\exp526
# Saved results to runs\detect\exp526
#
# Saved 1 image to runs\detect\exp527
# Saved results to runs\detect\exp527
#
# Saved 1 image to runs\detect\exp528
# Saved results to runs\detect\exp528
#
# Saved 1 image to runs\detect\exp529
# Saved results to runs\detect\exp529
#
# Saved 1 image to runs\detect\exp530
# Saved results to runs\detect\exp530
#
# Saved 1 image to runs\detect\exp531
# Saved results to runs\detect\exp531
#
# Saved 1 image to runs\detect\exp532
# Saved results to runs\detect\exp532
#
# Saved 1 image to runs\detect\exp533
# Saved results to runs\detect\exp533
#
# Saved 1 image to runs\detect\exp534
# Saved results to runs\detect\exp534
#
# Saved 1 image to runs\detect\exp535
# Saved results to runs\detect\exp535
#
# Saved 1 image to runs\detect\exp536
# Saved results to runs\detect\exp536
#
# Saved 1 image to runs\detect\exp537
# Saved results to runs\detect\exp537
#
# Saved 1 image to runs\detect\exp538
# Saved results to runs\detect\exp538
#
# Saved 1 image to runs\detect\exp539
# Saved results to runs\detect\exp539
#
# Saved 1 image to runs\detect\exp540
# Saved results to runs\detect\exp540
#
# Saved 1 image to runs\detect\exp541
# Saved results to runs\detect\exp541
#
# Saved 1 image to runs\detect\exp542
# Saved results to runs\detect\exp542
#
# Saved 1 image to runs\detect\exp543
# Saved results to runs\detect\exp543
#
# Saved 1 image to runs\detect\exp544
# Saved results to runs\detect\exp544
#
# Saved 1 image to runs\detect\exp545
# Saved results to runs\detect\exp545
#
# Saved 1 image to runs\detect\exp546
# Saved results to runs\detect\exp546
#
# Saved 1 image to runs\detect\exp547
# Saved results to runs\detect\exp547
#
# Saved 1 image to runs\detect\exp548
# Saved results to runs\detect\exp548
#
# Saved 1 image to runs\detect\exp549
# Saved results to runs\detect\exp549
#
# Saved 1 image to runs\detect\exp550
# Saved results to runs\detect\exp550
#
# Saved 1 image to runs\detect\exp551
# Saved results to runs\detect\exp551
#
# Saved 1 image to runs\detect\exp552
# Saved results to runs\detect\exp552
#
# Saved 1 image to runs\detect\exp553
# Saved results to runs\detect\exp553
#
# Saved 1 image to runs\detect\exp554
# Saved results to runs\detect\exp554
#
# Saved 1 image to runs\detect\exp555
# Saved results to runs\detect\exp555
#
# Saved 1 image to runs\detect\exp556
# Saved results to runs\detect\exp556
#
# Saved 1 image to runs\detect\exp557
# Saved results to runs\detect\exp557
#
# Saved 1 image to runs\detect\exp558
# Saved results to runs\detect\exp558
#
# Saved 1 image to runs\detect\exp559
# Saved results to runs\detect\exp559
#
# Saved 1 image to runs\detect\exp560
# Saved results to runs\detect\exp560
#
# Saved 1 image to runs\detect\exp561
# Saved results to runs\detect\exp561
#
# Saved 1 image to runs\detect\exp562
# Saved results to runs\detect\exp562
#
# Saved 1 image to runs\detect\exp563
# Saved results to runs\detect\exp563
#
# Saved 1 image to runs\detect\exp564
# Saved results to runs\detect\exp564
#
# Saved 1 image to runs\detect\exp565
# Saved results to runs\detect\exp565
#
# Saved 1 image to runs\detect\exp566
# Saved results to runs\detect\exp566
#
# Saved 1 image to runs\detect\exp567
# Saved results to runs\detect\exp567
#
# Saved 1 image to runs\detect\exp568
# Saved results to runs\detect\exp568
#
# Saved 1 image to runs\detect\exp569
# Saved results to runs\detect\exp569
#
# Saved 1 image to runs\detect\exp570
# Saved results to runs\detect\exp570
#
# Saved 1 image to runs\detect\exp571
# Saved results to runs\detect\exp571
#
# Saved 1 image to runs\detect\exp572
# Saved results to runs\detect\exp572
#
# Saved 1 image to runs\detect\exp573
# Saved results to runs\detect\exp573
#
# Saved 1 image to runs\detect\exp574
# Saved results to runs\detect\exp574
#
# Saved 1 image to runs\detect\exp575
# Saved results to runs\detect\exp575
#
# Saved 1 image to runs\detect\exp576
# Saved results to runs\detect\exp576
#
# Saved 1 image to runs\detect\exp577
# Saved results to runs\detect\exp577
#
# Saved 1 image to runs\detect\exp578
# Saved results to runs\detect\exp578
#
# Saved 1 image to runs\detect\exp579
# Saved results to runs\detect\exp579
#
# Saved 1 image to runs\detect\exp580
# Saved results to runs\detect\exp580
#
# Saved 1 image to runs\detect\exp581
# Saved results to runs\detect\exp581
#
# Saved 1 image to runs\detect\exp582
# Saved results to runs\detect\exp582
#
# Saved 1 image to runs\detect\exp583
# Saved results to runs\detect\exp583
#
# Saved 1 image to runs\detect\exp584
# Saved results to runs\detect\exp584
#
# Saved 1 image to runs\detect\exp585
# Saved results to runs\detect\exp585
#
# Saved 1 image to runs\detect\exp586
# Saved results to runs\detect\exp586
#
# Saved 1 image to runs\detect\exp587
# Saved results to runs\detect\exp587
#
# Saved 1 image to runs\detect\exp588
# Saved results to runs\detect\exp588
#
# Saved 1 image to runs\detect\exp589
# Saved results to runs\detect\exp589
#
# Saved 1 image to runs\detect\exp590
# Saved results to runs\detect\exp590
#
# Saved 1 image to runs\detect\exp591
# Saved results to runs\detect\exp591
#
# Saved 1 image to runs\detect\exp592
# Saved results to runs\detect\exp592
#
# Saved 1 image to runs\detect\exp593
# Saved results to runs\detect\exp593
#
# Saved 1 image to runs\detect\exp594
# Saved results to runs\detect\exp594
#
# Saved 1 image to runs\detect\exp595
# Saved results to runs\detect\exp595
#
# Saved 1 image to runs\detect\exp596
# Saved results to runs\detect\exp596
#
# Saved 1 image to runs\detect\exp597
# Saved results to runs\detect\exp597
#
# Saved 1 image to runs\detect\exp598
# Saved results to runs\detect\exp598
#
# Saved 1 image to runs\detect\exp599
# Saved results to runs\detect\exp599
#
# Saved 1 image to runs\detect\exp600
# Saved results to runs\detect\exp600
#
# Saved 1 image to runs\detect\exp601
# Saved results to runs\detect\exp601
#
# Saved 1 image to runs\detect\exp602
# Saved results to runs\detect\exp602
# Inference time: 85.58 sec.
#                   sample_name                                      legend
# 0    20220915195651573677.png       ['drt' 'qn' '©' 'deo' 'RE' '@' 'ber']
# 1    20220915195652176684.png                                 ['On' 'Os']
# 2    20220915195652713648.png                                ['Mobility']
# 3    20220915195653681519.png                                     ['exe']
# 4    20220915195654121931.png                                         NaN
# ..                        ...                                         ...
# 295  20220915195931225632.png                         ['area' 'ad' 'IDA']
# 296  20220915195931982187.png                               ['+' 'Canes']
# 297  20220915195932679590.png                                     ['ge.']
# 298  20220915195933359877.png         ['MeV' 'Output' '(bar/m)' '&' 'x”']
# 299  20220915195934085444.png  ['ME' '@' 'power' '@' 'Titanium' '©' 'ax']
#
# [300 rows x 2 columns]
# The submission file   : results/REDA solutions_legend_detection_model_results.csv
